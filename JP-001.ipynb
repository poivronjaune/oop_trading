# %%
import pandas

from stockmarket.symbols import Symbols

# %%
symbols = Symbols()

# %%
nasdaq = symbols.filter(exchange='TSX')
nasdaq

# %%
tmp = symbols.all.copy()
filter1 = tmp.ExchangeCode == 'NASDAQ'
#filter2 = tmp.Type == 'EQUITY'
filter2 = None
tmp.loc[filter1 & filter2]
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# File c:\Workspace\Python\Stocks\3-oop_trading\env\lib\site-packages\pandas\core\ops\array_ops.py:301, in na_logical_op(x, y, op)
#     292 try:
#     293     # For exposition, write:
#     294     #  yarr = isinstance(y, np.ndarray)
#    (...)
#     299     # Then Cases where this goes through without raising include:
#     300     #  (xint or xbool) and (yint or bool)
# --> 301     result = op(x, y)
#     302 except TypeError:
#
# TypeError: unsupported operand type(s) for &: 'bool' and 'NoneType'
#
# During handling of the above exception, another exception occurred:
#
# ValueError                                Traceback (most recent call last)
# File c:\Workspace\Python\Stocks\3-oop_trading\env\lib\site-packages\pandas\core\ops\array_ops.py:315, in na_logical_op(x, y, op)
#     314 try:
# ...

# %%
tmp.loc[filter1]
# Out:
#                                  Name              Sector  \
# Symbol
# AACG        Ata Creativity Global ADR  Consumer Defensive
# AACI        Armada Acquisition Corp I  Financial Services
# AACIU       Armada Acquisition Corp I  Financial Services
# AACIW    Armada Acquisition Corp I WT                 NaN
# AADI             Aadi Biosciences Inc          Healthcare
# ...                               ...                 ...
# ZWRKU   Z-Work Acquisition Corp Units  Financial Services
# ZWRKW      Z-Work Acquisition Corp WT                 NaN
# ZY                       Zymergen Inc     Basic Materials
# ZYNE                Zynerba Pharma CS          Healthcare
# ZYXI                        Zynex Inc          Healthcare
#
#                                       Industry    Type  Source  \
# Symbol
# AACG             Education & Training Services  EQUITY     NaN
# AACI                           Shell Companies  EQUITY     NaN
# ...
